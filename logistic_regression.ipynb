# %%
from sklearn.linear_model import LogisticRegression

# %%
import pandas as pd
df=pd.read_csv("loan_data.csv")

# %%
df.head(20)
# Out:
#     person_age person_gender person_education  person_income  person_emp_exp  \
# 0         22.0        female           Master        71948.0               0
# 1         21.0        female      High School        12282.0               0
# 2         25.0        female      High School        12438.0               3
# 3         23.0        female         Bachelor        79753.0               0
# 4         24.0          male           Master        66135.0               1
# 5         21.0        female      High School        12951.0               0
# 6         26.0        female         Bachelor        93471.0               1
# 7         24.0        female      High School        95550.0               5
# 8         24.0        female        Associate       100684.0               3
# 9         21.0        female      High School        12739.0               0
# 10        22.0        female      High School       102985.0               0
# ...

# %%
df['person_education'].unique()
# Out:
# array([2, 0, 1, 4, 3])

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\krish\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\krish\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns  # Select categorical columns

# Count unique values in each categorical column
unique_counts = df[categorical_columns].nunique()
print(unique_counts)
# Out:
# person_gender                     2
# person_education                  5
# person_home_ownership             4
# loan_intent                       6
# previous_loan_defaults_on_file    2
# dtype: int64

# %%
df['person_gender']=df['person_gender'].map({'male':1,'female':0})
df['previous_loan_defaults_on_file']=df['previous_loan_defaults_on_file'].map({'Yes':1,'No':0})

# %%
edu={
    'High School': 0,
    'Bachelor': 1,
    'Master': 2,
    'Doctorate': 3,
    'Associate': 4
}
df['person_education']=df['person_education'].map(edu)

# %%
df = pd.get_dummies(df, columns=['person_home_ownership', 'loan_intent'], drop_first=True)

# %%
df.head(10)
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0        22.0              0                 2        71948.0               0
# 1        21.0              0                 0        12282.0               0
# 2        25.0              0                 0        12438.0               3
# 3        23.0              0                 1        79753.0               0
# 4        24.0              1                 2        66135.0               1
# 5        21.0              0                 0        12951.0               0
# 6        26.0              0                 1        93471.0               1
# 7        24.0              0                 0        95550.0               5
# 8        24.0              0                 4       100684.0               3
# 9        21.0              0                 0        12739.0               0
#
#    loan_amnt  loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# ...

# %%
df.head(10)
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0        22.0              0                 2        71948.0               0
# 1        21.0              0                 0        12282.0               0
# 2        25.0              0                 0        12438.0               3
# 3        23.0              0                 1        79753.0               0
# 4        24.0              1                 2        66135.0               1
# 5        21.0              0                 0        12951.0               0
# 6        26.0              0                 1        93471.0               1
# 7        24.0              0                 0        95550.0               5
# 8        24.0              0                 4       100684.0               3
# 9        21.0              0                 0        12739.0               0
#
#    loan_amnt  loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# ...

# %%
correlation_matrix = df.corr()  # Calculate the correlation matrix

# Display the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 correlation_matrix = df.corr()  # Calculate the correlation matrix
#       3 # Display the correlation matrix as a heatmap
# ----> 4 plt.figure(figsize=(10, 8))
#       5 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
#       6 plt.title("Correlation Matrix")
#
# NameError: name 'plt' is not defined

# %%
df['financial_maturity'] = df['person_age'] + df['person_emp_exp'] + df['cb_person_cred_hist_length'].round()

# %%
df=df.drop(['person_age','person_emp_exp','cb_person_cred_hist_length'],axis=1)

# %%
x=df.drop('loan_status' ,axis=1)
y=df['loan_status']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=4,train_size=0.6)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\krish\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8833888888888889
